# %% [markdown]
# # 20 - Baseline Training Experiments
#
# This notebook runs baseline training experiments across all data formats to compare:
# - Data loading throughput
# - Training time per epoch
# - Resource utilization (GPU, CPU, disk I/O)
# - Memory usage
#
# **Experiment Design:**
# - Simple ResNet-18 model
# - Fixed hyperparameters across all formats
# - 3 epochs for quick comparison
# - Same batch size and workers
# - Alternating run order to control for system state
#
# **Formats Tested:**
# 1. CSV (baseline)
# 2. WebDataset (shard256_none)
# 3. TFRecord (shard256_none)
# 4. LMDB (compress_none)
#
# **Output:**
# - Training metrics logged to `runs/<session>/summary.csv`
# - Resource monitoring logs per experiment

# %%
import os
import sys
import time
import json
from pathlib import Path
from collections import defaultdict

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from tqdm.auto import tqdm

# Load common utilities
# %run ./10_common_utils.ipynb
# Out:
# ✓ Common utilities loaded successfully
#
# Available functions:
#   - set_seed(seed)
#   - get_transforms(augment)
#   - write_sysinfo(path)
#   - time_first_batch(dataloader, device)
#   - start_monitor(log_path, interval)
#   - stop_monitor(thread, stop_event)
#   - append_to_summary(path, row_dict)
#   - compute_metrics_from_logs(log_path)
#   - get_device()
#   - format_bytes(bytes)
#   - count_parameters(model)
#
# Constants:
#   - STANDARD_TRANSFORM

# %% [markdown]
# ## Configuration

# %%
# Detect environment
IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ
BASE_DIR = Path('/kaggle/working/format-matters') if IS_KAGGLE else Path('..').resolve()

# Create run directory for this session
RUN_DIR = BASE_DIR / 'runs' / time.strftime('%Y%m%d-%H%M%S') / 'train_baselines'
RUN_DIR.mkdir(parents=True, exist_ok=True)

SUMMARY_CSV = RUN_DIR / 'summary.csv'
SUMMARY_CSV.touch(exist_ok=True)

print(f"Environment: {'Kaggle' if IS_KAGGLE else 'Local'}")
print(f"Base directory: {BASE_DIR}")
print(f"Run directory: {RUN_DIR}")
print(f"Summary log: {SUMMARY_CSV}")

# Write system info
write_sysinfo(RUN_DIR / 'sysinfo.json')
# Out:
# Environment: Local
# Base directory: C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters
# Run directory: C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines
# Summary log: C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\summary.csv
# ✓ System info written to C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\sysinfo.json

# %% [markdown]
# ## Training Configuration

# %%
# Training hyperparameters
CONFIG = {
    'batch_size': 64,
    'num_workers': 0,
    'num_epochs': 3,
    'learning_rate': 0.001,
    'momentum': 0.9,
    'weight_decay': 1e-4,
    'seed': 42,
}

# Formats to test (format_name, loader_notebook, variant)
FORMATS = [
    ('webdataset', '12_loader_webdataset.ipynb', 'shard256_none'),
    ('csv', '11_loader_csv.ipynb', 'default'),
    ('tfrecord', '13_loader_tfrecord.ipynb', 'shard256_none'),
    ('lmdb', '14_loader_lmdb.ipynb', 'compress_none'),
]

# Dataset to use (first available)
BUILT_DIR = BASE_DIR / 'data' / 'built'
DATASET = None
for ds in ['cifar10', 'imagenet-mini', 'tiny-imagenet-200']:
    if (BUILT_DIR / ds).exists():
        DATASET = ds
        break

if DATASET is None:
    raise RuntimeError("No datasets found. Run dataset preparation notebooks first.")

print(f"\nTraining Configuration:")
print(f"  Dataset: {DATASET}")
print(f"  Batch size: {CONFIG['batch_size']}")
print(f"  Num workers: {CONFIG['num_workers']}")
print(f"  Num epochs: {CONFIG['num_epochs']}")
print(f"  Learning rate: {CONFIG['learning_rate']}")
print(f"\nFormats to test: {len(FORMATS)}")
for fmt_name, _, variant in FORMATS:
    print(f"  - {fmt_name} ({variant})")
# Out:
# Training Configuration:
#   Dataset: cifar10
#   Batch size: 64
#   Num workers: 0
#   Num epochs: 3
#   Learning rate: 0.001
#
# Formats to test: 4
#   - webdataset (shard256_none)
#   - csv (default)
#   - tfrecord (shard256_none)
#   - lmdb (compress_none)

# %% [markdown]
# ## Model Definition

# %%
def create_model(num_classes: int, device: torch.device):
    """
    Create a ResNet-18 model for training.
    
    Args:
        num_classes: Number of output classes
        device: Device to place model on
    
    Returns:
        PyTorch model
    """
    model = models.resnet18(pretrained=False)
    
    # Modify final layer for num_classes
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    
    model = model.to(device)
    
    print(f"Model: ResNet-18")
    print(f"Parameters: {count_parameters(model):,}")
    print(f"Device: {device}")
    
    return model

# %% [markdown]
# ## Training Loop

# %%
def train_epoch(model, dataloader, criterion, optimizer, device, epoch):
    """
    Train for one epoch.
    
    Args:
        model: PyTorch model
        dataloader: Training dataloader
        criterion: Loss function
        optimizer: Optimizer
        device: Device to train on
        epoch: Current epoch number
    
    Returns:
        Dictionary with training metrics
    """
    model.train()
    
    total_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    
    start_time = time.time()
    
    pbar = tqdm(dataloader, desc=f"Epoch {epoch}")
    for batch_idx, (images, labels) in enumerate(pbar):
        num_batches += 1
        # Move to device
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass
        loss.backward()
        optimizer.step()
        
        # Statistics
        total_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
        # Update progress bar
        pbar.set_postfix({
            'loss': total_loss / num_batches,
            'acc': 100. * correct / total if total > 0 else 0.0
        })
    
    if num_batches == 0:
        raise RuntimeError('No batches were produced by the dataloader.')
    
    epoch_time = time.time() - start_time
    avg_loss = total_loss / num_batches
    accuracy = 100. * correct / total if total > 0 else 0.0
    throughput = total / epoch_time if epoch_time > 0 else 0.0
    
    return {
        'loss': avg_loss,
        'accuracy': accuracy,
        'time': epoch_time,
        'samples_per_sec': throughput,
    }


def validate(model, dataloader, criterion, device):
    """
    Validate the model.
    
    Args:
        model: PyTorch model
        dataloader: Validation dataloader
        criterion: Loss function
        device: Device to validate on
    
    Returns:
        Dictionary with validation metrics
    """
    model.eval()
    
    total_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    
    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Validation"):
            num_batches += 1
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
    
    if num_batches == 0:
        raise RuntimeError('No batches were produced by the validation dataloader.')
    
    avg_loss = total_loss / num_batches
    accuracy = 100. * correct / total if total > 0 else 0.0
    
    return {
        'loss': avg_loss,
        'accuracy': accuracy,
    }

# %% [markdown]
# ## Experiment Runner

# %%
def run_experiment(format_name, loader_notebook, variant, dataset, config, device):
    """
    Run training experiment for a single format.
    
    Args:
        format_name: Name of format (e.g., 'csv', 'webdataset')
        loader_notebook: Path to loader notebook
        variant: Format variant
        dataset: Dataset name
        config: Training configuration dict
        device: Device to train on
    
    Returns:
        Dictionary with experiment results
    """
    print(f"\n{'='*80}")
    print(f"Running experiment: {format_name} ({variant})")
    print(f"{'='*80}\n")
    
    # Set seed for reproducibility
    set_seed(config['seed'])
    
    # Load the appropriate dataloader
    print(f"Loading dataloader from {loader_notebook}...")
    # %run ./{loader_notebook}
    
    # Create dataloaders
    print(f"\nCreating dataloaders...")
    train_loader = make_dataloader(
        dataset=dataset,
        split='train',
        batch_size=config['batch_size'],
        num_workers=config['num_workers'],
        variant=variant,
        shuffle=True,
        pin_memory=True
    )
    
    val_loader = make_dataloader(
        dataset=dataset,
        split='val',
        batch_size=config['batch_size'],
        num_workers=config['num_workers'],
        variant=variant,
        shuffle=False,
        pin_memory=True
    )
    
    # Determine number of classes
    if dataset == 'cifar10':
        num_classes = 10
    elif dataset == 'tiny-imagenet-200':
        num_classes = 200
    else:
        num_classes = 1000  # imagenet-mini
    
    # Create model
    print(f"\nCreating model...")
    model = create_model(num_classes, device)
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(),
        lr=config['learning_rate'],
        momentum=config['momentum'],
        weight_decay=config['weight_decay']
    )
    
    # Start resource monitoring
    log_path = RUN_DIR / f"{format_name}_{variant}_metrics.csv"
    monitor_thread, stop_event = start_monitor(log_path, interval=0.5)
    
    # Training loop
    print(f"\nStarting training for {config['num_epochs']} epochs...\n")
    
    experiment_start = time.time()
    epoch_results = []
    
    for epoch in range(1, config['num_epochs'] + 1):
        # Train
        train_metrics = train_epoch(
            model, train_loader, criterion, optimizer, device, epoch
        )
        
        # Validate
        val_metrics = validate(model, val_loader, criterion, device)
        
        # Log results
        epoch_result = {
            'epoch': epoch,
            'train_loss': train_metrics['loss'],
            'train_acc': train_metrics['accuracy'],
            'train_time': train_metrics['time'],
            'train_samples_per_sec': train_metrics['samples_per_sec'],
            'val_loss': val_metrics['loss'],
            'val_acc': val_metrics['accuracy'],
        }
        epoch_results.append(epoch_result)
        
        print(f"\nEpoch {epoch} Summary:")
        print(f"  Train Loss: {train_metrics['loss']:.4f}, Acc: {train_metrics['accuracy']:.2f}%")
        print(f"  Val Loss: {val_metrics['loss']:.4f}, Acc: {val_metrics['accuracy']:.2f}%")
        print(f"  Time: {train_metrics['time']:.2f}s, Throughput: {train_metrics['samples_per_sec']:.1f} samples/s")
    
    total_time = time.time() - experiment_start
    
    # Stop resource monitoring
    stop_monitor(monitor_thread, stop_event)
    
    # Compute resource metrics
    resource_metrics = compute_metrics_from_logs(log_path)
    
    # Compile results
    results = {
        'format': format_name,
        'variant': variant,
        'dataset': dataset,
        'total_time': total_time,
        'epochs': epoch_results,
        'resources': resource_metrics,
    }
    
    # Log to summary CSV
    for epoch_result in epoch_results:
        row = {
            'stage': 'train',
            'format': format_name,
            'variant': variant,
            'dataset': dataset,
            **epoch_result,
            **resource_metrics,
        }
        append_to_summary(SUMMARY_CSV, row)
    
    print(f"\n✓ Experiment completed in {total_time:.2f}s")
    print(f"  Final train acc: {epoch_results[-1]['train_acc']:.2f}%")
    print(f"  Final val acc: {epoch_results[-1]['val_acc']:.2f}%")
    
    return results

# %% [markdown]
# ## Run All Experiments

# %%
# Get device
device = get_device()
print(f"Using device: {device}\n")

# Run experiments
all_results = []

for format_name, loader_notebook, variant in FORMATS:
    try:
        results = run_experiment(
            format_name=format_name,
            loader_notebook=loader_notebook,
            variant=variant,
            dataset=DATASET,
            config=CONFIG,
            device=device
        )
        all_results.append(results)
        
        # Small delay between experiments
        time.sleep(5)
        
    except Exception as e:
        print(f"\n✗ Experiment failed for {format_name}: {e}")
        import traceback
        traceback.print_exc()
        continue

print(f"\n{'='*80}")
print(f"All experiments completed!")
print(f"{'='*80}")
# Out:
# Using device: cpu
#
#
# ================================================================================
# Running experiment: webdataset (shard256_none)
# ================================================================================
#
# ✓ Random seed set to 42
# Loading dataloader from 12_loader_webdataset.ipynb...
# ✓ Common utilities loaded successfully
#
# Available functions:
#   - set_seed(seed)
#   - get_transforms(augment)
#   - write_sysinfo(path)
#   - time_first_batch(dataloader, device)
#   - start_monitor(log_path, interval)
#   - stop_monitor(thread, stop_event)
#   - append_to_summary(path, row_dict)
#   - compute_metrics_from_logs(log_path)
#   - get_device()
#   - format_bytes(bytes)
#   - count_parameters(model)
#
# Constants:
#   - STANDARD_TRANSFORM
# Running WebDataset DataLoader smoke test...
#
# Testing with dataset: cifar10, variant: shard1024_none
#
# Found 1 shard(s) for cifar10/train (shard1024_none)
# Example files: ['train-000000.tar']
#
# DataLoader created:
#   Batch size: 32
#   Num workers: 0
#   Variant: shard1024_none
# [('cifar10', 'shard1024_none'), ('cifar10', 'shard1024_zstd'), ('cifar10', 'shard256_none'), ('cifar10', 'shard256_zstd'), ('cifar10', 'shard64_none'), ('cifar10', 'shard64_zstd'), ('imagenet-mini', 'shard1024_none'), ('imagenet-mini', 'shard1024_zstd'), ('imagenet-mini', 'shard256_none'), ('imagenet-mini', 'shard256_zstd'), ('imagenet-mini', 'shard64_none'), ('imagenet-mini', 'shard64_zstd')]
#
# Loading first batch...
# First batch took 0.07s
#
# Batch shapes:
#   Images: torch.Size([16, 3, 224, 224]) (torch.float32)
#   Labels: torch.Size([16]) (torch.int64)
#   Image range: [-2.049, 2.640]
#   Label range: [0, 0]
#
# Testing throughput (10 batches)...
# 10 batches took 0.26s
#
# ✓ WebDataset DataLoader smoke test passed!
#
# Creating dataloaders...
# Found 1 shard(s) for cifar10/train (shard256_none)
# Example files: ['train-000000.tar']
# Found 1 shard(s) for cifar10/val (shard256_none)
# Example files: ['val-000000.tar']
#
# Creating model...
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Model: ResNet-18
# Parameters: 11,181,642
# Device: cpu
# ✓ Resource monitoring started (logging to C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\webdataset_shard256_none_metrics.csv)
#
# Starting training for 3 epochs...
# Epoch 1: 0it [00:00, ?it/s]
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Validation: 0it [00:00, ?it/s]
# Epoch 1 Summary:
#   Train Loss: 1.4466, Acc: 49.54%
#   Val Loss: 1.8776, Acc: 36.00%
#   Time: 2405.47s, Throughput: 20.8 samples/s
# Epoch 2: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 2 Summary:
#   Train Loss: 1.2536, Acc: 58.00%
#   Val Loss: 1.6444, Acc: 40.76%
#   Time: 2475.04s, Throughput: 20.2 samples/s
# Epoch 3: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 3 Summary:
#   Train Loss: 1.1481, Acc: 61.74%
#   Val Loss: 1.5785, Acc: 43.45%
#   Time: 2444.17s, Throughput: 20.5 samples/s
# ✓ Resource monitoring stopped
#
# ✓ Experiment completed in 7874.65s
#   Final train acc: 61.74%
#   Final val acc: 43.45%
#
# ================================================================================
# Running experiment: csv (default)
# ================================================================================
#
# ✓ Random seed set to 42
# Loading dataloader from 11_loader_csv.ipynb...
# ✓ Common utilities loaded successfully
#
# Available functions:
#   - set_seed(seed)
#   - get_transforms(augment)
#   - write_sysinfo(path)
#   - time_first_batch(dataloader, device)
#   - start_monitor(log_path, interval)
#   - stop_monitor(thread, stop_event)
#   - append_to_summary(path, row_dict)
#   - compute_metrics_from_logs(log_path)
#   - get_device()
#   - format_bytes(bytes)
#   - count_parameters(model)
#
# Constants:
#   - STANDARD_TRANSFORM
# Running CSV DataLoader smoke test...
#
# Testing with dataset: cifar10
#
# Loaded CSV dataset: 50000 samples from train.csv
#
# DataLoader created:
#   Dataset size: 50,000
#   Batch size: 16
#   Num batches: 3,125
#   Num workers: 0
#
# Loading first batch...
# Loading sample 0/50000
# Loading sample 10/50000
# First batch took 0.04s
#
# Batch shapes:
#   Images: torch.Size([16, 3, 224, 224]) (torch.float32)
#   Labels: torch.Size([16]) (torch.int64)
#   Image range: [-2.118, 2.640]
#   Label range: [0, 0]
#
# Testing throughput (10 batches)...
# Loading sample 0/50000
# Loading sample 10/50000
# Loading sample 20/50000
# Loading sample 30/50000
# Loading sample 40/50000
# Loading sample 50/50000
# Loading sample 60/50000
# Loading sample 70/50000
# Loading sample 80/50000
# Loading sample 90/50000
# Loading sample 100/50000
# Loading sample 110/50000
# Loading sample 120/50000
# Loading sample 130/50000
# Loading sample 140/50000
# Loading sample 150/50000
# 10 batches took 0.36s
#
# ✓ CSV DataLoader smoke test passed!
#
# Creating dataloaders...
# Loaded CSV dataset: 50000 samples from train.csv
# Loaded CSV dataset: 10000 samples from val.csv
#
# Creating model...
# Model: ResNet-18
# Parameters: 11,181,642
# Device: cpu
# ✓ Resource monitoring started (logging to C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\csv_default_metrics.csv)
#
# Starting training for 3 epochs...
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch 1:   0%|          | 0/782 [00:00<?, ?it/s]
# Loading sample 25310/50000
# Loading sample 8560/50000
# Loading sample 7790/50000
# Loading sample 20170/50000
# Loading sample 35360/50000
# Loading sample 37960/50000
# Loading sample 7150/50000
# Loading sample 41150/50000
# Loading sample 12830/50000
# Loading sample 23030/50000
# Loading sample 21290/50000
# Loading sample 21660/50000
# Loading sample 1130/50000
# Loading sample 39390/50000
# Loading sample 13890/50000
# Loading sample 31200/50000
# Loading sample 15620/50000
# Loading sample 37900/50000
# Loading sample 42940/50000
# Loading sample 41700/50000
# Loading sample 140/50000
# Loading sample 33490/50000
# Loading sample 29480/50000
# Loading sample 10140/50000
# Loading sample 45360/50000
# Loading sample 22640/50000
# Loading sample 9120/50000
# Loading sample 22950/50000
# Loading sample 17320/50000
# Loading sample 2050/50000
# Loading sample 38930/50000
# Loading sample 40190/50000
# Loading sample 27000/50000
# Loading sample 7680/50000
# Loading sample 33680/50000
# Loading sample 30620/50000
# Loading sample 24040/50000
# Loading sample 18390/50000
# Loading sample 11370/50000
# Loading sample 42420/50000
# Loading sample 13980/50000
# Loading sample 22540/50000
# Loading sample 4120/50000
# Loading sample 3790/50000
# Loading sample 27530/50000
# Loading sample 18840/50000
# Loading sample 34610/50000
# Loading sample 41160/50000
# Loading sample 32350/50000
# Loading sample 5860/50000
# Loading sample 31250/50000
# Loading sample 41420/50000
# Loading sample 9150/50000
# Loading sample 7200/50000
# Loading sample 13400/50000
# Loading sample 12440/50000
# Loading sample 8090/50000
# Loading sample 11340/50000
# Loading sample 40950/50000
# Loading sample 27580/50000
# Loading sample 46860/50000
# Loading sample 42660/50000
# Loading sample 7710/50000
# Loading sample 10900/50000
# Loading sample 41680/50000
# Loading sample 13330/50000
# Loading sample 38430/50000
# Loading sample 25460/50000
# Loading sample 46710/50000
# Loading sample 38050/50000
# Loading sample 13740/50000
# Loading sample 6670/50000
# Loading sample 13220/50000
# Loading sample 33610/50000
# Loading sample 39520/50000
# Loading sample 28960/50000
# Loading sample 29780/50000
# Loading sample 16220/50000
# Loading sample 14510/50000
# Loading sample 25590/50000
# Loading sample 6290/50000
# Loading sample 5720/50000
# Loading sample 47600/50000
# Loading sample 34490/50000
# Loading sample 36780/50000
# Loading sample 39720/50000
# Loading sample 33230/50000
# Loading sample 28640/50000
# Loading sample 27710/50000
# Loading sample 26080/50000
# Loading sample 2850/50000
# Loading sample 38820/50000
# Loading sample 21810/50000
# Loading sample 800/50000
# Loading sample 15010/50000
# Loading sample 13520/50000
# Loading sample 37240/50000
# Loading sample 35490/50000
# Loading sample 26670/50000
# Loading sample 48920/50000
# Loading sample 35030/50000
# Loading sample 43190/50000
# Loading sample 26300/50000
# Loading sample 9230/50000
# Loading sample 31920/50000
# Loading sample 34680/50000
# Loading sample 37470/50000
# Loading sample 45420/50000
# Loading sample 21270/50000
# Loading sample 36160/50000
# Loading sample 40700/50000
# Loading sample 1080/50000
# Loading sample 37410/50000
# Loading sample 24940/50000
# Loading sample 31660/50000
# Loading sample 23830/50000
# Loading sample 9000/50000
# Loading sample 31400/50000
# Loading sample 27770/50000
# Loading sample 6580/50000
# Loading sample 45860/50000
# Loading sample 37160/50000
# Loading sample 19300/50000
# Loading sample 29510/50000
# Loading sample 1440/50000
# Loading sample 44520/50000
# Loading sample 14980/50000
# Loading sample 3330/50000
# Loading sample 40100/50000
# Loading sample 38550/50000
# Loading sample 23890/50000
# Loading sample 49930/50000
# Loading sample 25920/50000
# Loading sample 47160/50000
# Loading sample 26890/50000
# Loading sample 2780/50000
# Loading sample 49000/50000
# Loading sample 3820/50000
# Loading sample 5300/50000
# Loading sample 35870/50000
# Loading sample 5820/50000
# Loading sample 13240/50000
# Loading sample 1450/50000
# Loading sample 36050/50000
# Loading sample 28280/50000
# Loading sample 25780/50000
# Loading sample 21930/50000
# Loading sample 41520/50000
# Loading sample 11300/50000
# Loading sample 28030/50000
# Loading sample 33450/50000
# Loading sample 34830/50000
# Loading sample 19160/50000
# Loading sample 33240/50000
# Loading sample 35310/50000
# Loading sample 3120/50000
# Loading sample 37300/50000
# Loading sample 13340/50000
# Loading sample 23410/50000
# Loading sample 26650/50000
# Loading sample 32680/50000
# Loading sample 7590/50000
# Loading sample 8530/50000
# Loading sample 41090/50000
# Loading sample 21460/50000
# Loading sample 16170/50000
# Loading sample 16400/50000
# Loading sample 16440/50000
# Loading sample 35500/50000
# Loading sample 23770/50000
# Loading sample 40280/50000
# Loading sample 26910/50000
# Loading sample 16140/50000
# Loading sample 9890/50000
# Loading sample 33600/50000
# Loading sample 5030/50000
# Loading sample 21670/50000
# Loading sample 32090/50000
# Loading sample 27260/50000
# Loading sample 22030/50000
# Loading sample 31490/50000
# Loading sample 29100/50000
# Loading sample 12560/50000
# Loading sample 35570/50000
# Loading sample 27330/50000
# Loading sample 34450/50000
# Loading sample 40330/50000
# Loading sample 5930/50000
# Loading sample 41540/50000
# Loading sample 49260/50000
# Loading sample 13880/50000
# Loading sample 4010/50000
# Loading sample 15470/50000
# Loading sample 40810/50000
# Loading sample 44590/50000
# Loading sample 2730/50000
# Loading sample 41220/50000
# Loading sample 37060/50000
# Loading sample 28180/50000
# Loading sample 1860/50000
# Loading sample 48400/50000
# Loading sample 30930/50000
# Loading sample 15660/50000
# Loading sample 16020/50000
# Loading sample 23250/50000
# Loading sample 11270/50000
# Loading sample 36720/50000
# Loading sample 18400/50000
# Loading sample 38680/50000
# Loading sample 8730/50000
# Loading sample 34050/50000
# Loading sample 23870/50000
# Loading sample 22240/50000
# Loading sample 280/50000
# Loading sample 21430/50000
# Loading sample 42990/50000
# Loading sample 40620/50000
# Loading sample 33750/50000
# Loading sample 27480/50000
# Loading sample 49780/50000
# Loading sample 7690/50000
# Loading sample 2090/50000
# Loading sample 15150/50000
# Loading sample 3730/50000
# Loading sample 20730/50000
# Loading sample 3290/50000
# Loading sample 33520/50000
# Loading sample 4150/50000
# Loading sample 15170/50000
# Loading sample 12220/50000
# Loading sample 36370/50000
# Loading sample 47830/50000
# Loading sample 32920/50000
# Loading sample 49090/50000
# Loading sample 40720/50000
# Loading sample 27100/50000
# Loading sample 33840/50000
# Loading sample 18660/50000
# Loading sample 19130/50000
# Loading sample 4920/50000
# Loading sample 5420/50000
# Loading sample 14330/50000
# Loading sample 47780/50000
# Loading sample 19460/50000
# Loading sample 18950/50000
# Loading sample 47730/50000
# Loading sample 11470/50000
# Loading sample 48500/50000
# Loading sample 40540/50000
# Loading sample 18990/50000
# Loading sample 16090/50000
# Loading sample 11030/50000
# Loading sample 5360/50000
# Loading sample 5880/50000
# Loading sample 41460/50000
# Loading sample 28830/50000
# Loading sample 9590/50000
# Loading sample 19030/50000
# Loading sample 30010/50000
# Loading sample 41630/50000
# Loading sample 6620/50000
# Loading sample 25000/50000
# Loading sample 36320/50000
# Loading sample 35230/50000
# Loading sample 20890/50000
# Loading sample 37620/50000
# Loading sample 44160/50000
# Loading sample 17280/50000
# Loading sample 27850/50000
# Loading sample 45530/50000
# Loading sample 1270/50000
# Loading sample 28430/50000
# Loading sample 26310/50000
# Loading sample 16270/50000
# Loading sample 9050/50000
# Loading sample 39360/50000
# Loading sample 26290/50000
# Loading sample 19220/50000
# Loading sample 27520/50000
# Loading sample 8870/50000
# Loading sample 15100/50000
# Loading sample 42450/50000
# Loading sample 28880/50000
# Loading sample 46690/50000
# Loading sample 7830/50000
# Loading sample 39580/50000
# Loading sample 2810/50000
# Loading sample 37810/50000
# Loading sample 9110/50000
# Loading sample 3030/50000
# Loading sample 14640/50000
# Loading sample 32660/50000
# Loading sample 8310/50000
# Loading sample 29730/50000
# Loading sample 35850/50000
# Loading sample 26740/50000
# Loading sample 8220/50000
# Loading sample 49790/50000
# Loading sample 28330/50000
# Loading sample 20190/50000
# Loading sample 14840/50000
# Loading sample 47150/50000
# Loading sample 32240/50000
# Loading sample 49520/50000
# Loading sample 13620/50000
# Loading sample 38290/50000
# Loading sample 44640/50000
# Loading sample 29930/50000
# Loading sample 22980/50000
# Loading sample 24320/50000
# Loading sample 41620/50000
# Loading sample 21820/50000
# Loading sample 47820/50000
# Loading sample 24460/50000
# Loading sample 4710/50000
# Loading sample 42800/50000
# Loading sample 43910/50000
# Loading sample 30090/50000
# Loading sample 8490/50000
# Loading sample 29150/50000
# Loading sample 14290/50000
# Loading sample 27300/50000
# Loading sample 47120/50000
# Loading sample 34850/50000
# Loading sample 47560/50000
# Loading sample 34530/50000
# Loading sample 15920/50000
# Loading sample 43880/50000
# Loading sample 2720/50000
# Loading sample 4320/50000
# Loading sample 16530/50000
# Loading sample 25170/50000
# Loading sample 13790/50000
# Loading sample 24170/50000
# Loading sample 29070/50000
# Loading sample 23400/50000
# Loading sample 48070/50000
# Loading sample 39130/50000
# Loading sample 6190/50000
# Loading sample 10160/50000
# Loading sample 9180/50000
# Loading sample 28840/50000
# Loading sample 38040/50000
# Loading sample 13440/50000
# Loading sample 25470/50000
# Loading sample 7880/50000
# Loading sample 37780/50000
# Loading sample 34780/50000
# Loading sample 18640/50000
# Loading sample 34970/50000
# Loading sample 42670/50000
# Loading sample 37030/50000
# Loading sample 21190/50000
# Loading sample 44120/50000
# Loading sample 30370/50000
# Loading sample 9840/50000
# Loading sample 26680/50000
# Loading sample 4820/50000
# Loading sample 25750/50000
# Loading sample 28050/50000
# Loading sample 7990/50000
# Loading sample 23330/50000
# Loading sample 44710/50000
# Loading sample 34770/50000
# Loading sample 25540/50000
# Loading sample 6450/50000
# Loading sample 24610/50000
# Loading sample 2970/50000
# Loading sample 6930/50000
# Loading sample 23140/50000
# Loading sample 19610/50000
# Loading sample 1290/50000
# Loading sample 29740/50000
# Loading sample 7800/50000
# Loading sample 40370/50000
# Loading sample 3490/50000
# Loading sample 29320/50000
# Loading sample 8770/50000
# Loading sample 30510/50000
# Loading sample 39900/50000
# Loading sample 22190/50000
# Loading sample 30920/50000
# Loading sample 3280/50000
# Loading sample 43820/50000
# Loading sample 3040/50000
# Loading sample 43140/50000
# Loading sample 2980/50000
# Loading sample 60/50000
# Loading sample 38520/50000
# Loading sample 19120/50000
# Loading sample 6340/50000
# Loading sample 21970/50000
# Loading sample 17740/50000
# Loading sample 46460/50000
# Loading sample 42640/50000
# Loading sample 650/50000
# Loading sample 2800/50000
# Loading sample 10510/50000
# Loading sample 41070/50000
# Loading sample 25400/50000
# Loading sample 3160/50000
# Loading sample 22770/50000
# Loading sample 4650/50000
# Loading sample 43170/50000
# Loading sample 37500/50000
# Loading sample 2150/50000
# Loading sample 40240/50000
# Loading sample 6550/50000
# Loading sample 42650/50000
# Loading sample 5200/50000
# Loading sample 27780/50000
# Loading sample 4430/50000
# Loading sample 37460/50000
# Loading sample 25130/50000
# Loading sample 28040/50000
# Loading sample 22210/50000
# Loading sample 28970/50000
# Loading sample 33350/50000
# Loading sample 43040/50000
# Loading sample 48670/50000
# Loading sample 24670/50000
# Loading sample 3830/50000
# Loading sample 31040/50000
# Loading sample 46740/50000
# Loading sample 17880/50000
# Loading sample 6160/50000
# Loading sample 20910/50000
# Loading sample 8010/50000
# Loading sample 36180/50000
# Loading sample 14770/50000
# Loading sample 13000/50000
# Loading sample 13860/50000
# Loading sample 33800/50000
# Loading sample 8210/50000
# Loading sample 49430/50000
# Loading sample 19570/50000
# Loading sample 6350/50000
# Loading sample 30870/50000
# Loading sample 10630/50000
# Loading sample 37310/50000
# Loading sample 35700/50000
# Loading sample 27940/50000
# Loading sample 31690/50000
# Loading sample 47520/50000
# Loading sample 19260/50000
# Loading sample 20390/50000
# Loading sample 1890/50000
# Loading sample 14080/50000
# Loading sample 31350/50000
# Loading sample 10370/50000
# Loading sample 11390/50000
# Loading sample 30730/50000
# Loading sample 18040/50000
# Loading sample 29640/50000
# Loading sample 23790/50000
# Loading sample 12860/50000
# Loading sample 44800/50000
# Loading sample 6720/50000
# Loading sample 38490/50000
# Loading sample 1800/50000
# Loading sample 49940/50000
# Loading sample 23570/50000
# Loading sample 42150/50000
# Loading sample 19400/50000
# Loading sample 33460/50000
# Loading sample 18770/50000
# Loading sample 4960/50000
# Loading sample 27340/50000
# Loading sample 37640/50000
# Loading sample 12250/50000
# Loading sample 30270/50000
# Loading sample 48180/50000
# Loading sample 49490/50000
# Loading sample 14100/50000
# Loading sample 31810/50000
# Loading sample 32530/50000
# Loading sample 22320/50000
# Loading sample 20670/50000
# Loading sample 710/50000
# Loading sample 28060/50000
# Loading sample 1000/50000
# Loading sample 43350/50000
# Loading sample 42400/50000
# Loading sample 4620/50000
# Loading sample 29140/50000
# Loading sample 30670/50000
# Loading sample 41020/50000
# Loading sample 29890/50000
# Loading sample 26770/50000
# Loading sample 5710/50000
# Loading sample 48760/50000
# Loading sample 38030/50000
# Loading sample 19450/50000
# Loading sample 14060/50000
# Loading sample 36570/50000
# Loading sample 34220/50000
# Loading sample 18890/50000
# Loading sample 18020/50000
# Loading sample 1310/50000
# Loading sample 7890/50000
# Loading sample 4100/50000
# Loading sample 25710/50000
# Loading sample 17440/50000
# Loading sample 30840/50000
# Loading sample 26380/50000
# Loading sample 28420/50000
# Loading sample 13160/50000
# Loading sample 33380/50000
# Loading sample 47020/50000
# Loading sample 45850/50000
# Loading sample 4560/50000
# Loading sample 46670/50000
# Loading sample 23930/50000
# Loading sample 40320/50000
# Loading sample 20010/50000
# Loading sample 29600/50000
# Loading sample 14630/50000
# Loading sample 11490/50000
# Loading sample 460/50000
# Loading sample 23620/50000
# Loading sample 2990/50000
# Loading sample 10790/50000
# Loading sample 29210/50000
# Loading sample 6430/50000
# Loading sample 46950/50000
# Loading sample 16520/50000
# Loading sample 16340/50000
# Loading sample 8120/50000
# Loading sample 43850/50000
# Loading sample 7910/50000
# Loading sample 42600/50000
# Loading sample 23230/50000
# Loading sample 27720/50000
# Loading sample 18870/50000
# Loading sample 41600/50000
# Loading sample 18580/50000
# Loading sample 31520/50000
# Loading sample 22530/50000
# Loading sample 48090/50000
# Loading sample 32950/50000
# Loading sample 21420/50000
# Loading sample 40640/50000
# Loading sample 7000/50000
# Loading sample 8700/50000
# Loading sample 9500/50000
# Loading sample 25560/50000
# Loading sample 42910/50000
# Loading sample 44280/50000
# Loading sample 40530/50000
# Loading sample 4760/50000
# Loading sample 8260/50000
# Loading sample 16380/50000
# Loading sample 37700/50000
# Loading sample 14720/50000
# Loading sample 7190/50000
# Loading sample 11620/50000
# Loading sample 38200/50000
# Loading sample 4240/50000
# Loading sample 34190/50000
# Loading sample 10260/50000
# Loading sample 15770/50000
# Loading sample 8660/50000
# Loading sample 34900/50000
# Loading sample 32220/50000
# Loading sample 37940/50000
# Loading sample 41870/50000
# Loading sample 49900/50000
# Loading sample 49120/50000
# Loading sample 29380/50000
# Loading sample 16720/50000
# Loading sample 30330/50000
# Loading sample 36260/50000
# Loading sample 22380/50000
# Loading sample 42370/50000
# Loading sample 38450/50000
# Loading sample 17830/50000
# Loading sample 3620/50000
# Loading sample 15890/50000
# Loading sample 47310/50000
# Loading sample 44030/50000
# Loading sample 24770/50000
# Loading sample 16590/50000
# Loading sample 31010/50000
# Loading sample 31070/50000
# Loading sample 16600/50000
# Loading sample 7100/50000
# Loading sample 37020/50000
# Loading sample 38170/50000
# Loading sample 8520/50000
# Loading sample 20770/50000
# Loading sample 39810/50000
# Loading sample 25530/50000
# Loading sample 29490/50000
# Loading sample 8230/50000
# Loading sample 45480/50000
# Loading sample 45060/50000
# Loading sample 49820/50000
# Loading sample 28750/50000
# Loading sample 48430/50000
# Loading sample 39070/50000
# Loading sample 44870/50000
# Loading sample 49170/50000
# Loading sample 18110/50000
# Loading sample 20830/50000
# Loading sample 12020/50000
# Loading sample 170/50000
# Loading sample 45430/50000
# Loading sample 25870/50000
# Loading sample 21070/50000
# Loading sample 24580/50000
# Loading sample 38570/50000
# Loading sample 2920/50000
# Loading sample 27050/50000
# Loading sample 39190/50000
# Loading sample 13910/50000
# Loading sample 31850/50000
# Loading sample 9270/50000
# Loading sample 17060/50000
# Loading sample 30800/50000
# Loading sample 27120/50000
# Loading sample 12380/50000
# Loading sample 34030/50000
# Loading sample 41350/50000
# Loading sample 29960/50000
# Loading sample 19340/50000
# Loading sample 2230/50000
# Loading sample 8060/50000
# Loading sample 21920/50000
# Loading sample 47800/50000
# Loading sample 43730/50000
# Loading sample 26900/50000
# Loading sample 21530/50000
# Loading sample 15180/50000
# Loading sample 15690/50000
# Loading sample 33900/50000
# Loading sample 22870/50000
# Loading sample 39600/50000
# Loading sample 7290/50000
# Loading sample 15480/50000
# Loading sample 37010/50000
# Loading sample 36880/50000
# Loading sample 27030/50000
# Loading sample 20490/50000
# Loading sample 45050/50000
# Loading sample 12480/50000
# Loading sample 23840/50000
# Loading sample 19780/50000
# Loading sample 2600/50000
# Loading sample 12030/50000
# Loading sample 21940/50000
# Loading sample 22890/50000
# Loading sample 45440/50000
# Loading sample 4300/50000
# Loading sample 32420/50000
# Loading sample 46750/50000
# Loading sample 7510/50000
# Loading sample 35190/50000
# Loading sample 27690/50000
# Loading sample 11010/50000
# Loading sample 16450/50000
# Loading sample 4020/50000
# Loading sample 38880/50000
# Loading sample 26980/50000
# Loading sample 5600/50000
# Loading sample 37760/50000
# Loading sample 8150/50000
# Loading sample 31020/50000
# Loading sample 1210/50000
# Loading sample 1030/50000
# Loading sample 25840/50000
# Loading sample 13170/50000
# Loading sample 33870/50000
# Loading sample 39540/50000
# Loading sample 10010/50000
# Loading sample 40510/50000
# Loading sample 17930/50000
# Loading sample 1910/50000
# Loading sample 1730/50000
# Loading sample 6240/50000
# Loading sample 17520/50000
# Loading sample 1110/50000
# Loading sample 48900/50000
# Loading sample 42610/50000
# Loading sample 10100/50000
# Loading sample 24410/50000
# Loading sample 10680/50000
# Loading sample 4640/50000
# Loading sample 100/50000
# Loading sample 23470/50000
# Loading sample 31050/50000
# Loading sample 42960/50000
# Loading sample 29870/50000
# Loading sample 22060/50000
# Loading sample 19430/50000
# Loading sample 47630/50000
# Loading sample 15500/50000
# Loading sample 43870/50000
# Loading sample 34840/50000
# Loading sample 22800/50000
# Loading sample 32620/50000
# Loading sample 30110/50000
# Loading sample 20540/50000
# Loading sample 180/50000
# Loading sample 18150/50000
# Loading sample 36590/50000
# Loading sample 16230/50000
# Loading sample 25200/50000
# Loading sample 32150/50000
# Loading sample 37380/50000
# Loading sample 35000/50000
# Loading sample 8840/50000
# Loading sample 17210/50000
# Loading sample 1740/50000
# Loading sample 10540/50000
# Loading sample 10210/50000
# Loading sample 28340/50000
# Loading sample 3450/50000
# Loading sample 12990/50000
# Loading sample 36300/50000
# Loading sample 11930/50000
# Loading sample 46010/50000
# Loading sample 14030/50000
# Loading sample 49440/50000
# Loading sample 6050/50000
# Loading sample 14190/50000
# Loading sample 6390/50000
# Loading sample 15640/50000
# Loading sample 4050/50000
# Loading sample 7460/50000
# Loading sample 21910/50000
# Loading sample 31120/50000
# Loading sample 37600/50000
# Loading sample 18730/50000
# Loading sample 48050/50000
# Loading sample 6170/50000
# Loading sample 15680/50000
# Loading sample 15080/50000
# Loading sample 940/50000
# Loading sample 26010/50000
# Loading sample 9240/50000
# Loading sample 15740/50000
# Loading sample 8860/50000
# Loading sample 25580/50000
# Loading sample 36450/50000
# Loading sample 24620/50000
# Loading sample 46340/50000
# Loading sample 12230/50000
# Loading sample 20810/50000
# Loading sample 8740/50000
# Loading sample 36110/50000
# Loading sample 41780/50000
# Loading sample 5250/50000
# Loading sample 14320/50000
# Loading sample 11640/50000
# Loading sample 19580/50000
# Loading sample 46360/50000
# Loading sample 36900/50000
# Loading sample 19900/50000
# Loading sample 1620/50000
# Loading sample 44530/50000
# Loading sample 46140/50000
# Loading sample 15900/50000
# Loading sample 32460/50000
# Loading sample 32470/50000
# Loading sample 9760/50000
# Loading sample 27630/50000
# Loading sample 25210/50000
# Loading sample 36950/50000
# Loading sample 6180/50000
# Loading sample 30150/50000
# Loading sample 5700/50000
# Loading sample 15070/50000
# Loading sample 20440/50000
# Loading sample 49610/50000
# Loading sample 28630/50000
# Loading sample 46920/50000
# Loading sample 14860/50000
# Loading sample 38590/50000
# Loading sample 42580/50000
# Loading sample 18330/50000
# Loading sample 2390/50000
# Loading sample 40970/50000
# Loading sample 26180/50000
# Loading sample 18260/50000
# Loading sample 27010/50000
# Loading sample 47660/50000
# Loading sample 1070/50000
# Loading sample 38850/50000
# Loading sample 3360/50000
# Loading sample 23780/50000
# Loading sample 23190/50000
# Loading sample 27660/50000
# Loading sample 1770/50000
# Loading sample 21100/50000
# Loading sample 24540/50000
# Loading sample 21200/50000
# Loading sample 25010/50000
# Loading sample 44150/50000
# Loading sample 48880/50000
# Loading sample 29120/50000
# Loading sample 14990/50000
# Loading sample 24340/50000
# Loading sample 21030/50000
# Loading sample 21600/50000
# Loading sample 39500/50000
# Loading sample 46540/50000
# Loading sample 49300/50000
# Loading sample 19840/50000
# Loading sample 11250/50000
# Loading sample 35410/50000
# Loading sample 1940/50000
# Loading sample 37430/50000
# Loading sample 24900/50000
# Loading sample 30960/50000
# Loading sample 44140/50000
# Loading sample 35560/50000
# Loading sample 45670/50000
# Loading sample 19960/50000
# Loading sample 33810/50000
# Loading sample 42510/50000
# Loading sample 9640/50000
# Loading sample 24600/50000
# Loading sample 12500/50000
# Loading sample 8510/50000
# Loading sample 41030/50000
# Loading sample 14300/50000
# Loading sample 12160/50000
# Loading sample 11480/50000
# Loading sample 4870/50000
# Loading sample 6220/50000
# Loading sample 27110/50000
# Loading sample 9730/50000
# Loading sample 19370/50000
# Loading sample 34380/50000
# Loading sample 37070/50000
# Loading sample 26410/50000
# Loading sample 30850/50000
# Loading sample 8070/50000
# Loading sample 22650/50000
# Loading sample 11060/50000
# Loading sample 40070/50000
# Loading sample 46970/50000
# Loading sample 42820/50000
# Loading sample 26790/50000
# Loading sample 35140/50000
# Loading sample 5520/50000
# Loading sample 31100/50000
# Loading sample 37150/50000
# Loading sample 23610/50000
# Loading sample 23720/50000
# Loading sample 45220/50000
# Loading sample 12370/50000
# Loading sample 31190/50000
# Loading sample 2530/50000
# Loading sample 44250/50000
# Loading sample 21130/50000
# Loading sample 7920/50000
# Loading sample 3970/50000
# Loading sample 32010/50000
# Loading sample 30580/50000
# Loading sample 35920/50000
# Loading sample 37110/50000
# Loading sample 20100/50000
# Loading sample 40850/50000
# Loading sample 19680/50000
# Loading sample 31710/50000
# Loading sample 290/50000
# Loading sample 46180/50000
# Loading sample 45640/50000
# Loading sample 18200/50000
# Loading sample 35620/50000
# Loading sample 24050/50000
# Loading sample 9790/50000
# Loading sample 43700/50000
# Loading sample 45790/50000
# Loading sample 17140/50000
# Loading sample 20860/50000
# Loading sample 39920/50000
# Loading sample 37910/50000
# Loading sample 37320/50000
# Loading sample 3550/50000
# Loading sample 7220/50000
# Loading sample 16110/50000
# Loading sample 42360/50000
# Loading sample 37750/50000
# Loading sample 33560/50000
# Loading sample 39230/50000
# Loading sample 11320/50000
# Loading sample 14310/50000
# Loading sample 35890/50000
# Loading sample 4000/50000
# Loading sample 15270/50000
# Loading sample 13370/50000
# Loading sample 19270/50000
# Loading sample 46160/50000
# Loading sample 29340/50000
# Loading sample 34510/50000
# Loading sample 830/50000
# Loading sample 37450/50000
# Loading sample 10860/50000
# Loading sample 38580/50000
# Loading sample 1760/50000
# Loading sample 6910/50000
# Loading sample 4190/50000
# Loading sample 32770/50000
# Loading sample 40710/50000
# Loading sample 6090/50000
# Loading sample 32910/50000
# Loading sample 49990/50000
# Loading sample 9950/50000
# Loading sample 18680/50000
# Loading sample 43490/50000
# Loading sample 21980/50000
# Loading sample 18350/50000
# Loading sample 30570/50000
# Loading sample 10650/50000
# Loading sample 23970/50000
# Loading sample 690/50000
# Loading sample 33080/50000
# Loading sample 12100/50000
# Loading sample 8790/50000
# Loading sample 46760/50000
# Loading sample 2870/50000
# Loading sample 27390/50000
# Loading sample 40580/50000
# Loading sample 7010/50000
# Loading sample 38460/50000
# Loading sample 20150/50000
# Loading sample 5570/50000
# Loading sample 340/50000
# Loading sample 47920/50000
# Loading sample 4140/50000
# Loading sample 40010/50000
# Loading sample 7750/50000
# Loading sample 18300/50000
# Loading sample 1670/50000
# Loading sample 33820/50000
# Loading sample 24560/50000
# Loading sample 37130/50000
# Loading sample 16470/50000
# Loading sample 47190/50000
# Loading sample 26330/50000
# Loading sample 39880/50000
# Loading sample 27760/50000
# Loading sample 36280/50000
# Loading sample 18230/50000
# Loading sample 24640/50000
# Loading sample 25970/50000
# Loading sample 26840/50000
# Loading sample 42480/50000
# Loading sample 33340/50000
# Loading sample 22680/50000
# Loading sample 43330/50000
# Loading sample 4910/50000
# Loading sample 17840/50000
# Loading sample 11580/50000
# Loading sample 21680/50000
# Loading sample 36850/50000
# Loading sample 17870/50000
# Loading sample 14440/50000
# Loading sample 29540/50000
# Loading sample 25670/50000
# Loading sample 14670/50000
# Loading sample 46900/50000
# Loading sample 19690/50000
# Loading sample 39710/50000
# Loading sample 40290/50000
# Loading sample 35680/50000
# Loading sample 7640/50000
# Loading sample 1930/50000
# Loading sample 6560/50000
# Loading sample 21720/50000
# Loading sample 6570/50000
# Loading sample 26930/50000
# Loading sample 10040/50000
# Loading sample 36550/50000
# Loading sample 42070/50000
# Loading sample 31220/50000
# Loading sample 26120/50000
# Loading sample 39010/50000
# Loading sample 12320/50000
# Loading sample 39560/50000
# Loading sample 41660/50000
# Loading sample 44720/50000
# Loading sample 48620/50000
# Loading sample 46410/50000
# Loading sample 35110/50000
# Loading sample 24030/50000
# Loading sample 1690/50000
# Loading sample 33130/50000
# Loading sample 11110/50000
# Loading sample 20450/50000
# Loading sample 29590/50000
# Loading sample 42780/50000
# Loading sample 9160/50000
# Loading sample 33400/50000
# Loading sample 38670/50000
# Loading sample 18760/50000
# Loading sample 46310/50000
# Loading sample 12350/50000
# Loading sample 40350/50000
# Loading sample 17370/50000
# Loading sample 47540/50000
# Loading sample 24550/50000
# Loading sample 33570/50000
# Loading sample 40400/50000
# Loading sample 36200/50000
# Loading sample 31550/50000
# Loading sample 27170/50000
# Loading sample 24180/50000
# Loading sample 22750/50000
# Loading sample 30220/50000
# Loading sample 23450/50000
# Loading sample 13270/50000
# Loading sample 5320/50000
# Loading sample 13650/50000
# Loading sample 37880/50000
# Loading sample 16890/50000
# Loading sample 30500/50000
# Loading sample 17980/50000
# Loading sample 30630/50000
# Loading sample 4270/50000
# Loading sample 22450/50000
# Loading sample 43110/50000
# Loading sample 17000/50000
# Loading sample 13490/50000
# Loading sample 33530/50000
# Loading sample 23110/50000
# Loading sample 24490/50000
# Loading sample 30100/50000
# Loading sample 42240/50000
# Loading sample 3570/50000
# Loading sample 38210/50000
# Loading sample 47250/50000
# Loading sample 32810/50000
# Loading sample 49550/50000
# Loading sample 590/50000
# Loading sample 39110/50000
# Loading sample 44730/50000
# Loading sample 34640/50000
# Loading sample 36410/50000
# Loading sample 22090/50000
# Loading sample 120/50000
# Loading sample 43010/50000
# Loading sample 32750/50000
# Loading sample 5630/50000
# Loading sample 27800/50000
# Loading sample 7720/50000
# Loading sample 41080/50000
# Loading sample 23900/50000
# Loading sample 4480/50000
# Loading sample 12790/50000
# Loading sample 44830/50000
# Loading sample 26810/50000
# Loading sample 35810/50000
# Loading sample 23210/50000
# Loading sample 40860/50000
# Loading sample 8420/50000
# Loading sample 930/50000
# Loading sample 46940/50000
# Loading sample 34750/50000
# Loading sample 29220/50000
# Loading sample 16620/50000
# Loading sample 18450/50000
# Loading sample 39400/50000
# Loading sample 14170/50000
# Loading sample 48970/50000
# Loading sample 27440/50000
# Loading sample 21010/50000
# Loading sample 33390/50000
# Loading sample 38400/50000
# Loading sample 12620/50000
# Loading sample 36460/50000
# Loading sample 3100/50000
# Loading sample 39250/50000
# Loading sample 16610/50000
# Loading sample 1060/50000
# Loading sample 29190/50000
# Loading sample 23730/50000
# Loading sample 7270/50000
# Loading sample 26320/50000
# Loading sample 190/50000
# Loading sample 20070/50000
# Loading sample 6600/50000
# Loading sample 10610/50000
# Loading sample 22790/50000
# Loading sample 40960/50000
# Loading sample 22290/50000
# Loading sample 4110/50000
# Loading sample 48240/50000
# Loading sample 880/50000
# Loading sample 27130/50000
# Loading sample 3210/50000
# Loading sample 40590/50000
# Loading sample 43840/50000
# Loading sample 21740/50000
# Loading sample 40360/50000
# Loading sample 42740/50000
# Loading sample 32540/50000
# Loading sample 1920/50000
# Loading sample 32980/50000
# Loading sample 15930/50000
# Loading sample 12980/50000
# Loading sample 27040/50000
# Loading sample 10410/50000
# Loading sample 23290/50000
# Loading sample 5490/50000
# Loading sample 32610/50000
# Loading sample 560/50000
# Loading sample 31320/50000
# Loading sample 11840/50000
# Loading sample 43500/50000
# Loading sample 21400/50000
# Loading sample 26220/50000
# Loading sample 44040/50000
# Loading sample 47350/50000
# Loading sample 33700/50000
# Loading sample 11310/50000
# Loading sample 26750/50000
# Loading sample 42680/50000
# Loading sample 37590/50000
# Loading sample 40830/50000
# Loading sample 27840/50000
# Loading sample 9710/50000
# Loading sample 27960/50000
# Loading sample 22410/50000
# Loading sample 46720/50000
# Loading sample 8670/50000
# Loading sample 18240/50000
# Loading sample 2440/50000
# Loading sample 13380/50000
# Loading sample 17960/50000
# Loading sample 4830/50000
# Loading sample 15230/50000
# Loading sample 39820/50000
# Loading sample 42900/50000
# Loading sample 49180/50000
# Loading sample 11560/50000
# Loading sample 4880/50000
# Loading sample 8140/50000
# Loading sample 1530/50000
# Loading sample 23690/50000
# Loading sample 32500/50000
# Loading sample 3380/50000
# Loading sample 41510/50000
# Loading sample 3980/50000
# Loading sample 34700/50000
# Loading sample 17240/50000
# Loading sample 20160/50000
# Loading sample 1220/50000
# Loading sample 35740/50000
# Loading sample 18560/50000
# Loading sample 8350/50000
# Loading sample 22370/50000
# Loading sample 33030/50000
# Loading sample 34170/50000
# Loading sample 28940/50000
# Loading sample 43320/50000
# Loading sample 41690/50000
# Loading sample 23630/50000
# Loading sample 4460/50000
# Loading sample 7340/50000
# Loading sample 32300/50000
# Loading sample 36560/50000
# Loading sample 43650/50000
# Loading sample 36920/50000
# Loading sample 6870/50000
# Loading sample 34930/50000
# Loading sample 22350/50000
# Loading sample 20110/50000
# Loading sample 3220/50000
# Loading sample 35130/50000
# Loading sample 21550/50000
# Loading sample 17350/50000
# Loading sample 5590/50000
# Loading sample 36970/50000
# Loading sample 24290/50000
# Loading sample 37990/50000
# Loading sample 25760/50000
# Loading sample 3300/50000
# Loading sample 32270/50000
# Loading sample 26350/50000
# Loading sample 14870/50000
# Loading sample 24010/50000
# Loading sample 34020/50000
# Loading sample 32760/50000
# Loading sample 43390/50000
# Loading sample 24830/50000
# Loading sample 12940/50000
# Loading sample 25500/50000
# Loading sample 8130/50000
# Loading sample 19740/50000
# Loading sample 20210/50000
# Loading sample 47910/50000
# Loading sample 9740/50000
# Loading sample 34150/50000
# Loading sample 10600/50000
# Loading sample 22280/50000
# Loading sample 1970/50000
# Loading sample 5280/50000
# Loading sample 35050/50000
# Loading sample 36120/50000
# Loading sample 2640/50000
# Loading sample 12610/50000
# Loading sample 41000/50000
# Loading sample 42330/50000
# Loading sample 31230/50000
# Loading sample 45080/50000
# Loading sample 41110/50000
# Loading sample 32480/50000
# Loading sample 25250/50000
# Loading sample 1180/50000
# Loading sample 31460/50000
# Loading sample 18420/50000
# Loading sample 28540/50000
# Loading sample 270/50000
# Loading sample 24870/50000
# Loading sample 9310/50000
# Loading sample 20040/50000
# Loading sample 36800/50000
# Loading sample 29040/50000
# Loading sample 12640/50000
# Loading sample 2520/50000
# Loading sample 8320/50000
# Loading sample 16370/50000
# Loading sample 27820/50000
# Loading sample 12680/50000
# Loading sample 47950/50000
# Loading sample 19360/50000
# Loading sample 44550/50000
# Loading sample 770/50000
# Loading sample 35350/50000
# Loading sample 36960/50000
# Loading sample 25820/50000
# Loading sample 1230/50000
# Loading sample 1340/50000
# Loading sample 17030/50000
# Loading sample 41560/50000
# Loading sample 6500/50000
# Loading sample 33260/50000
# Loading sample 7350/50000
# Loading sample 12280/50000
# Loading sample 41860/50000
# Loading sample 36090/50000
# Loading sample 33320/50000
# Loading sample 10880/50000
# Loading sample 24390/50000
# Loading sample 39680/50000
# Loading sample 45140/50000
# Loading sample 22160/50000
# Loading sample 8330/50000
# Loading sample 41130/50000
# Loading sample 10740/50000
# Loading sample 22480/50000
# Loading sample 25380/50000
# Loading sample 25550/50000
# Loading sample 31030/50000
# Loading sample 6590/50000
# Loading sample 40180/50000
# Loading sample 18160/50000
# Loading sample 47640/50000
# Loading sample 4890/50000
# Loading sample 2820/50000
# Loading sample 45310/50000
# Loading sample 50/50000
# Loading sample 18100/50000
# Loading sample 30700/50000
# Loading sample 17970/50000
# Loading sample 43370/50000
# Loading sample 34870/50000
# Loading sample 4470/50000
# Loading sample 15360/50000
# Loading sample 15630/50000
# Loading sample 49230/50000
# Loading sample 25950/50000
# Loading sample 150/50000
# Loading sample 32070/50000
# Loading sample 1200/50000
# Loading sample 9430/50000
# Loading sample 45070/50000
# Loading sample 40900/50000
# Loading sample 3480/50000
# Loading sample 46300/50000
# Loading sample 32890/50000
# Loading sample 46880/50000
# Loading sample 10380/50000
# Loading sample 2030/50000
# Loading sample 47200/50000
# Loading sample 11220/50000
# Loading sample 23710/50000
# Loading sample 13550/50000
# Loading sample 19290/50000
# Loading sample 32280/50000
# Loading sample 48510/50000
# Loading sample 16330/50000
# Loading sample 46650/50000
# Loading sample 21840/50000
# Loading sample 10480/50000
# Loading sample 47300/50000
# Loading sample 9910/50000
# Loading sample 3530/50000
# Loading sample 49860/50000
# Loading sample 2320/50000
# Loading sample 4600/50000
# Loading sample 39890/50000
# Loading sample 25020/50000
# Loading sample 37720/50000
# Loading sample 45200/50000
# Loading sample 25030/50000
# Loading sample 30240/50000
# Loading sample 6130/50000
# Loading sample 1840/50000
# Loading sample 14750/50000
# Loading sample 42430/50000
# Loading sample 10580/50000
# Loading sample 6980/50000
# Loading sample 11610/50000
# Loading sample 18590/50000
# Loading sample 10300/50000
# Loading sample 2860/50000
# Loading sample 23580/50000
# Loading sample 21450/50000
# Loading sample 23040/50000
# Loading sample 16560/50000
# Loading sample 25290/50000
# Loading sample 14530/50000
# Loading sample 3150/50000
# Loading sample 3810/50000
# Loading sample 36080/50000
# Loading sample 11360/50000
# Loading sample 27200/50000
# Loading sample 39030/50000
# Loading sample 36210/50000
# Loading sample 41760/50000
# Loading sample 20320/50000
# Loading sample 950/50000
# Loading sample 44420/50000
# Loading sample 25330/50000
# Loading sample 36070/50000
# Loading sample 9280/50000
# Loading sample 14560/50000
# Loading sample 49060/50000
# Loading sample 36360/50000
# Loading sample 34320/50000
# Loading sample 31900/50000
# Loading sample 12580/50000
# Loading sample 9260/50000
# Loading sample 550/50000
# Loading sample 3670/50000
# Loading sample 10720/50000
# Loading sample 13290/50000
# Loading sample 31240/50000
# Loading sample 30490/50000
# Loading sample 2550/50000
# Loading sample 23550/50000
# Loading sample 15530/50000
# Loading sample 49390/50000
# Loading sample 40420/50000
# Loading sample 43080/50000
# Loading sample 7480/50000
# Loading sample 44210/50000
# Loading sample 44080/50000
# Loading sample 13450/50000
# Loading sample 20600/50000
# Loading sample 20550/50000
# Loading sample 41550/50000
# Loading sample 440/50000
# Loading sample 44820/50000
# Loading sample 28100/50000
# Loading sample 13250/50000
# Loading sample 17290/50000
# Loading sample 39590/50000
# Loading sample 32870/50000
# Loading sample 49310/50000
# Loading sample 12700/50000
# Loading sample 40760/50000
# Loading sample 14370/50000
# Loading sample 5130/50000
# Loading sample 13010/50000
# Loading sample 7450/50000
# Loading sample 2080/50000
# Loading sample 38240/50000
# Loading sample 35660/50000
# Loading sample 750/50000
# Loading sample 41610/50000
# Loading sample 48870/50000
# Loading sample 17050/50000
# Loading sample 44260/50000
# Loading sample 6850/50000
# Loading sample 32390/50000
# Loading sample 34910/50000
# Loading sample 4260/50000
# Loading sample 22010/50000
# Loading sample 35380/50000
# Loading sample 12730/50000
# Loading sample 210/50000
# Loading sample 37870/50000
# Loading sample 29250/50000
# Loading sample 48110/50000
# Loading sample 17510/50000
# Loading sample 44680/50000
# Loading sample 1500/50000
# Loading sample 28850/50000
# Loading sample 5430/50000
# Loading sample 7600/50000
# Loading sample 26460/50000
# Loading sample 15790/50000
# Loading sample 19050/50000
# Loading sample 46980/50000
# Loading sample 37560/50000
# Loading sample 16130/50000
# Loading sample 27540/50000
# Loading sample 38690/50000
# Loading sample 23340/50000
# Loading sample 34670/50000
# Loading sample 24510/50000
# Loading sample 27670/50000
# Loading sample 23060/50000
# Loading sample 600/50000
# Loading sample 11870/50000
# Loading sample 40470/50000
# Loading sample 46780/50000
# Loading sample 27310/50000
# Loading sample 25850/50000
# Loading sample 11860/50000
# Loading sample 42570/50000
# Loading sample 6380/50000
# Loading sample 38100/50000
# Loading sample 41250/50000
# Loading sample 7400/50000
# Loading sample 39340/50000
# Loading sample 13540/50000
# Loading sample 32290/50000
# Loading sample 6410/50000
# Loading sample 43310/50000
# Loading sample 23300/50000
# Loading sample 38220/50000
# Loading sample 20820/50000
# Loading sample 45870/50000
# Loading sample 1600/50000
# Loading sample 17590/50000
# Loading sample 32930/50000
# Loading sample 39750/50000
# Loading sample 5070/50000
# Loading sample 20290/50000
# Loading sample 25880/50000
# Loading sample 28070/50000
# Loading sample 11660/50000
# Loading sample 31940/50000
# Loading sample 8920/50000
# Loading sample 23800/50000
# Loading sample 46330/50000
# Loading sample 28470/50000
# Loading sample 26400/50000
# Loading sample 28720/50000
# Loading sample 21220/50000
# Loading sample 30940/50000
# Loading sample 3200/50000
# Loading sample 30440/50000
# Loading sample 45490/50000
# Loading sample 12140/50000
# Loading sample 36810/50000
# Loading sample 37350/50000
# Loading sample 10820/50000
# Loading sample 35200/50000
# Loading sample 26150/50000
# Loading sample 15440/50000
# Loading sample 29400/50000
# Loading sample 21990/50000
# Loading sample 37100/50000
# Loading sample 28490/50000
# Loading sample 41800/50000
# Loading sample 28090/50000
# Loading sample 42290/50000
# Loading sample 29710/50000
# Loading sample 12900/50000
# Loading sample 48380/50000
# Loading sample 15560/50000
# Loading sample 46000/50000
# Loading sample 1750/50000
# Loading sample 7550/50000
# Loading sample 17150/50000
# Loading sample 21260/50000
# Loading sample 27920/50000
# Loading sample 31780/50000
# Loading sample 10960/50000
# Loading sample 31330/50000
# Loading sample 44310/50000
# Loading sample 27680/50000
# Loading sample 24880/50000
# Loading sample 20840/50000
# Loading sample 31930/50000
# Loading sample 17390/50000
# Loading sample 22990/50000
# Loading sample 27470/50000
# Loading sample 3390/50000
# Loading sample 14110/50000
# Loading sample 45650/50000
# Loading sample 15730/50000
# Loading sample 23380/50000
# Loading sample 8690/50000
# Loading sample 40690/50000
# Loading sample 42550/50000
# Loading sample 34590/50000
# Loading sample 40150/50000
# Loading sample 28080/50000
# Loading sample 19930/50000
# Loading sample 46510/50000
# Loading sample 14700/50000
# Loading sample 42380/50000
# Loading sample 37970/50000
# Loading sample 45840/50000
# Loading sample 630/50000
# Loading sample 9860/50000
# Loading sample 1150/50000
# Loading sample 9090/50000
# Loading sample 390/50000
# Loading sample 26280/50000
# Loading sample 26540/50000
# Loading sample 37360/50000
# Loading sample 37170/50000
# Loading sample 35150/50000
# Loading sample 18000/50000
# Loading sample 17780/50000
# Loading sample 25650/50000
# Loading sample 49500/50000
# Loading sample 29690/50000
# Loading sample 22390/50000
# Loading sample 20410/50000
# Loading sample 36540/50000
# Loading sample 13180/50000
# Loading sample 25350/50000
# Loading sample 47860/50000
# Loading sample 48160/50000
# Loading sample 24100/50000
# Loading sample 21480/50000
# Loading sample 34720/50000
# Loading sample 44390/50000
# Loading sample 33670/50000
# ...
# Loading sample 6630/10000
# Loading sample 6640/10000
# Loading sample 6650/10000
# Loading sample 6660/10000
# Loading sample 6670/10000
# Loading sample 6680/10000
# Loading sample 6690/10000
# Loading sample 6700/10000
# Loading sample 6710/10000
# Loading sample 6720/10000
# Loading sample 6730/10000
# Loading sample 6740/10000
# Loading sample 6750/10000
# Loading sample 6760/10000
# Loading sample 6770/10000
# Loading sample 6780/10000
# Loading sample 6790/10000
# Loading sample 6800/10000
# Loading sample 6810/10000
# Loading sample 6820/10000
# Loading sample 6830/10000
# Loading sample 6840/10000
# Loading sample 6850/10000
# Loading sample 6860/10000
# Loading sample 6870/10000
# Loading sample 6880/10000
# Loading sample 6890/10000
# Loading sample 6900/10000
# Loading sample 6910/10000
# Loading sample 6920/10000
# Loading sample 6930/10000
# Loading sample 6940/10000
# Loading sample 6950/10000
# Loading sample 6960/10000
# Loading sample 6970/10000
# Loading sample 6980/10000
# Loading sample 6990/10000
# Loading sample 7000/10000
# Loading sample 7010/10000
# Loading sample 7020/10000
# Loading sample 7030/10000
# Loading sample 7040/10000
# Loading sample 7050/10000
# Loading sample 7060/10000
# Loading sample 7070/10000
# Loading sample 7080/10000
# Loading sample 7090/10000
# Loading sample 7100/10000
# Loading sample 7110/10000
# Loading sample 7120/10000
# Loading sample 7130/10000
# Loading sample 7140/10000
# Loading sample 7150/10000
# Loading sample 7160/10000
# Loading sample 7170/10000
# Loading sample 7180/10000
# Loading sample 7190/10000
# Loading sample 7200/10000
# Loading sample 7210/10000
# Loading sample 7220/10000
# Loading sample 7230/10000
# Loading sample 7240/10000
# Loading sample 7250/10000
# Loading sample 7260/10000
# Loading sample 7270/10000
# Loading sample 7280/10000
# Loading sample 7290/10000
# Loading sample 7300/10000
# Loading sample 7310/10000
# Loading sample 7320/10000
# Loading sample 7330/10000
# Loading sample 7340/10000
# Loading sample 7350/10000
# Loading sample 7360/10000
# Loading sample 7370/10000
# Loading sample 7380/10000
# Loading sample 7390/10000
# Loading sample 7400/10000
# Loading sample 7410/10000
# Loading sample 7420/10000
# Loading sample 7430/10000
# Loading sample 7440/10000
# Loading sample 7450/10000
# Loading sample 7460/10000
# Loading sample 7470/10000
# Loading sample 7480/10000
# Loading sample 7490/10000
# Loading sample 7500/10000
# Loading sample 7510/10000
# Loading sample 7520/10000
# Loading sample 7530/10000
# Loading sample 7540/10000
# Loading sample 7550/10000
# Loading sample 7560/10000
# Loading sample 7570/10000
# Loading sample 7580/10000
# Loading sample 7590/10000
# Loading sample 7600/10000
# Loading sample 7610/10000
# Loading sample 7620/10000
# Loading sample 7630/10000
# Loading sample 7640/10000
# Loading sample 7650/10000
# Loading sample 7660/10000
# Loading sample 7670/10000
# Loading sample 7680/10000
# Loading sample 7690/10000
# Loading sample 7700/10000
# Loading sample 7710/10000
# Loading sample 7720/10000
# Loading sample 7730/10000
# Loading sample 7740/10000
# Loading sample 7750/10000
# Loading sample 7760/10000
# Loading sample 7770/10000
# Loading sample 7780/10000
# Loading sample 7790/10000
# Loading sample 7800/10000
# Loading sample 7810/10000
# Loading sample 7820/10000
# Loading sample 7830/10000
# Loading sample 7840/10000
# Loading sample 7850/10000
# Loading sample 7860/10000
# Loading sample 7870/10000
# Loading sample 7880/10000
# Loading sample 7890/10000
# Loading sample 7900/10000
# Loading sample 7910/10000
# Loading sample 7920/10000
# Loading sample 7930/10000
# Loading sample 7940/10000
# Loading sample 7950/10000
# Loading sample 7960/10000
# Loading sample 7970/10000
# Loading sample 7980/10000
# Loading sample 7990/10000
# Loading sample 8000/10000
# Loading sample 8010/10000
# Loading sample 8020/10000
# Loading sample 8030/10000
# Loading sample 8040/10000
# Loading sample 8050/10000
# Loading sample 8060/10000
# Loading sample 8070/10000
# Loading sample 8080/10000
# Loading sample 8090/10000
# Loading sample 8100/10000
# Loading sample 8110/10000
# Loading sample 8120/10000
# Loading sample 8130/10000
# Loading sample 8140/10000
# Loading sample 8150/10000
# Loading sample 8160/10000
# Loading sample 8170/10000
# Loading sample 8180/10000
# Loading sample 8190/10000
# Loading sample 8200/10000
# Loading sample 8210/10000
# Loading sample 8220/10000
# Loading sample 8230/10000
# Loading sample 8240/10000
# Loading sample 8250/10000
# Loading sample 8260/10000
# Loading sample 8270/10000
# Loading sample 8280/10000
# Loading sample 8290/10000
# Loading sample 8300/10000
# Loading sample 8310/10000
# Loading sample 8320/10000
# Loading sample 8330/10000
# Loading sample 8340/10000
# Loading sample 8350/10000
# Loading sample 8360/10000
# Loading sample 8370/10000
# Loading sample 8380/10000
# Loading sample 8390/10000
# Loading sample 8400/10000
# Loading sample 8410/10000
# Loading sample 8420/10000
# Loading sample 8430/10000
# Loading sample 8440/10000
# Loading sample 8450/10000
# Loading sample 8460/10000
# Loading sample 8470/10000
# Loading sample 8480/10000
# Loading sample 8490/10000
# Loading sample 8500/10000
# Loading sample 8510/10000
# Loading sample 8520/10000
# Loading sample 8530/10000
# Loading sample 8540/10000
# Loading sample 8550/10000
# Loading sample 8560/10000
# Loading sample 8570/10000
# Loading sample 8580/10000
# Loading sample 8590/10000
# Loading sample 8600/10000
# Loading sample 8610/10000
# Loading sample 8620/10000
# Loading sample 8630/10000
# Loading sample 8640/10000
# Loading sample 8650/10000
# Loading sample 8660/10000
# Loading sample 8670/10000
# Loading sample 8680/10000
# Loading sample 8690/10000
# Loading sample 8700/10000
# Loading sample 8710/10000
# Loading sample 8720/10000
# Loading sample 8730/10000
# Loading sample 8740/10000
# Loading sample 8750/10000
# Loading sample 8760/10000
# Loading sample 8770/10000
# Loading sample 8780/10000
# Loading sample 8790/10000
# Loading sample 8800/10000
# Loading sample 8810/10000
# Loading sample 8820/10000
# Loading sample 8830/10000
# Loading sample 8840/10000
# Loading sample 8850/10000
# Loading sample 8860/10000
# Loading sample 8870/10000
# Loading sample 8880/10000
# Loading sample 8890/10000
# Loading sample 8900/10000
# Loading sample 8910/10000
# Loading sample 8920/10000
# Loading sample 8930/10000
# Loading sample 8940/10000
# Loading sample 8950/10000
# Loading sample 8960/10000
# Loading sample 8970/10000
# Loading sample 8980/10000
# Loading sample 8990/10000
# Loading sample 9000/10000
# Loading sample 9010/10000
# Loading sample 9020/10000
# Loading sample 9030/10000
# Loading sample 9040/10000
# Loading sample 9050/10000
# Loading sample 9060/10000
# Loading sample 9070/10000
# Loading sample 9080/10000
# Loading sample 9090/10000
# Loading sample 9100/10000
# Loading sample 9110/10000
# Loading sample 9120/10000
# Loading sample 9130/10000
# Loading sample 9140/10000
# Loading sample 9150/10000
# Loading sample 9160/10000
# Loading sample 9170/10000
# Loading sample 9180/10000
# Loading sample 9190/10000
# Loading sample 9200/10000
# Loading sample 9210/10000
# Loading sample 9220/10000
# Loading sample 9230/10000
# Loading sample 9240/10000
# Loading sample 9250/10000
# Loading sample 9260/10000
# Loading sample 9270/10000
# Loading sample 9280/10000
# Loading sample 9290/10000
# Loading sample 9300/10000
# Loading sample 9310/10000
# Loading sample 9320/10000
# Loading sample 9330/10000
# Loading sample 9340/10000
# Loading sample 9350/10000
# Loading sample 9360/10000
# Loading sample 9370/10000
# Loading sample 9380/10000
# Loading sample 9390/10000
# Loading sample 9400/10000
# Loading sample 9410/10000
# Loading sample 9420/10000
# Loading sample 9430/10000
# Loading sample 9440/10000
# Loading sample 9450/10000
# Loading sample 9460/10000
# Loading sample 9470/10000
# Loading sample 9480/10000
# Loading sample 9490/10000
# Loading sample 9500/10000
# Loading sample 9510/10000
# Loading sample 9520/10000
# Loading sample 9530/10000
# Loading sample 9540/10000
# Loading sample 9550/10000
# Loading sample 9560/10000
# Loading sample 9570/10000
# Loading sample 9580/10000
# Loading sample 9590/10000
# Loading sample 9600/10000
# Loading sample 9610/10000
# Loading sample 9620/10000
# Loading sample 9630/10000
# Loading sample 9640/10000
# Loading sample 9650/10000
# Loading sample 9660/10000
# Loading sample 9670/10000
# Loading sample 9680/10000
# Loading sample 9690/10000
# Loading sample 9700/10000
# Loading sample 9710/10000
# Loading sample 9720/10000
# Loading sample 9730/10000
# Loading sample 9740/10000
# Loading sample 9750/10000
# Loading sample 9760/10000
# Loading sample 9770/10000
# Loading sample 9780/10000
# Loading sample 9790/10000
# Loading sample 9800/10000
# Loading sample 9810/10000
# Loading sample 9820/10000
# Loading sample 9830/10000
# Loading sample 9840/10000
# Loading sample 9850/10000
# Loading sample 9860/10000
# Loading sample 9870/10000
# Loading sample 9880/10000
# Loading sample 9890/10000
# Loading sample 9900/10000
# Loading sample 9910/10000
# Loading sample 9920/10000
# Loading sample 9930/10000
# Loading sample 9940/10000
# Loading sample 9950/10000
# Loading sample 9960/10000
# Loading sample 9970/10000
# Loading sample 9980/10000
# Loading sample 9990/10000
#
# Epoch 3 Summary:
#   Train Loss: 1.1158, Acc: 59.87%
#   Val Loss: 1.0801, Acc: 61.41%
#   Time: 2349.66s, Throughput: 21.3 samples/s
# ✓ Resource monitoring stopped
#
# ✓ Experiment completed in 7664.91s
#   Final train acc: 59.87%
#   Final val acc: 61.41%
#
# ================================================================================
# Running experiment: tfrecord (shard256_none)
# ================================================================================
#
# ✓ Random seed set to 42
# Loading dataloader from 13_loader_tfrecord.ipynb...
# ✓ Common utilities loaded successfully
#
# Available functions:
#   - set_seed(seed)
#   - get_transforms(augment)
#   - write_sysinfo(path)
#   - time_first_batch(dataloader, device)
#   - start_monitor(log_path, interval)
#   - stop_monitor(thread, stop_event)
#   - append_to_summary(path, row_dict)
#   - compute_metrics_from_logs(log_path)
#   - get_device()
#   - format_bytes(bytes)
#   - count_parameters(model)
#
# Constants:
#   - STANDARD_TRANSFORM
# Running TFRecord DataLoader smoke test...
#
# Testing with dataset: cifar10, variant: shard1024_gzip
#
# Found 1 shard(s) for cifar10/train (shard1024_gzip)
# Loaded TFRecord dataset: 1 shard(s)
#
# DataLoader created:
#   Batch size: 32
#   Num workers: 0
#   Variant: shard1024_gzip
#
# Loading first batch...
# First batch took 1.03s
#
# Batch shapes:
#   Images: torch.Size([32, 3, 224, 224]) (torch.float32)
#   Labels: torch.Size([32]) (torch.int64)
#   Image range: [-2.118, 2.640]
#   Label range: [0, 9]
#
# Testing throughput (10 batches)...
# 10 batches took 1.46s
#
# ✓ TFRecord DataLoader smoke test passed!
#
# Creating dataloaders...
# Found 1 shard(s) for cifar10/train (shard256_none)
# Loaded TFRecord dataset: 1 shard(s)
# Found 1 shard(s) for cifar10/val (shard256_none)
# Loaded TFRecord dataset: 1 shard(s)
#
# Creating model...
# Model: ResNet-18
# Parameters: 11,181,642
# Device: cpu
# ✓ Resource monitoring started (logging to C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\tfrecord_shard256_none_metrics.csv)
#
# Starting training for 3 epochs...
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch 1: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 1 Summary:
#   Train Loss: 1.6814, Acc: 37.66%
#   Val Loss: 1.5212, Acc: 43.79%
#   Time: 2370.93s, Throughput: 21.1 samples/s
# Epoch 2: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 2 Summary:
#   Train Loss: 1.3170, Acc: 52.35%
#   Val Loss: 1.2236, Acc: 55.09%
#   Time: 2361.28s, Throughput: 21.2 samples/s
# Epoch 3: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 3 Summary:
#   Train Loss: 1.1288, Acc: 59.04%
#   Val Loss: 1.1599, Acc: 58.42%
#   Time: 2358.10s, Throughput: 21.2 samples/s
# ✓ Resource monitoring stopped
#
# ✓ Experiment completed in 7625.80s
#   Final train acc: 59.04%
#   Final val acc: 58.42%
#
# ================================================================================
# Running experiment: lmdb (compress_none)
# ================================================================================
#
# ✓ Random seed set to 42
# Loading dataloader from 14_loader_lmdb.ipynb...
# ✓ Common utilities loaded successfully
#
# Available functions:
#   - set_seed(seed)
#   - get_transforms(augment)
#   - write_sysinfo(path)
#   - time_first_batch(dataloader, device)
#   - start_monitor(log_path, interval)
#   - stop_monitor(thread, stop_event)
#   - append_to_summary(path, row_dict)
#   - compute_metrics_from_logs(log_path)
#   - get_device()
#   - format_bytes(bytes)
#   - count_parameters(model)
#
# Constants:
#   - STANDARD_TRANSFORM
# Running LMDB DataLoader smoke test...
#
# Testing with dataset: cifar10, variant: compress_lz4
#
# Loaded LMDB dataset: 50,000 samples from train.lmdb
#   Compression: lz4
#
# DataLoader created:
#   Dataset size: 50,000
#   Batch size: 32
#   Num batches: 1,563
#   Num workers: 0
#   Variant: compress_lz4
#
# Loading first batch...
# First batch took 0.07s
#
# Batch shapes:
#   Images: torch.Size([32, 3, 224, 224]) (torch.float32)
#   Labels: torch.Size([32]) (torch.int64)
#   Image range: [-2.118, 2.640]
#   Label range: [0, 9]
#
# Testing throughput (10 batches)...
# 10 batches took 0.58s
#
# ✓ LMDB DataLoader smoke test passed!
#
# Creating dataloaders...
# Loaded LMDB dataset: 50,000 samples from train.lmdb
#   Compression: none
# Loaded LMDB dataset: 10,000 samples from val.lmdb
#   Compression: none
#
# Creating model...
# Model: ResNet-18
# Parameters: 11,181,642
# Device: cpu
# ✓ Resource monitoring started (logging to C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\lmdb_compress_none_metrics.csv)
#
# Starting training for 3 epochs...
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch 1:   0%|          | 0/782 [00:00<?, ?it/s]
# Validation:   0%|          | 0/157 [00:00<?, ?it/s]
# Epoch 1 Summary:
#   Train Loss: 1.6875, Acc: 37.38%
#   Val Loss: 1.4479, Acc: 46.98%
#   Time: 2324.72s, Throughput: 21.5 samples/s
# Epoch 2:   0%|          | 0/782 [00:00<?, ?it/s]
# Validation:   0%|          | 0/157 [00:00<?, ?it/s]
# Epoch 2 Summary:
#   Train Loss: 1.3210, Acc: 52.04%
#   Val Loss: 1.2647, Acc: 54.49%
#   Time: 2315.06s, Throughput: 21.6 samples/s
# Epoch 3:   0%|          | 0/782 [00:00<?, ?it/s]
# Validation:   0%|          | 0/157 [00:00<?, ?it/s]
# Epoch 3 Summary:
#   Train Loss: 1.1375, Acc: 59.36%
#   Val Loss: 1.1191, Acc: 59.79%
#   Time: 2322.17s, Throughput: 21.5 samples/s
# ✓ Resource monitoring stopped
#
# ✓ Experiment completed in 7475.59s
#   Final train acc: 59.36%
#   Final val acc: 59.79%
#
# ================================================================================
# All experiments completed!
# ================================================================================

# %% [markdown]
# ## Results Summary

# %%
import pandas as pd

if SUMMARY_CSV.exists() and SUMMARY_CSV.stat().st_size > 0:
    df = pd.read_csv(SUMMARY_CSV)
    
    print("\n" + "="*80)
    print("BASELINE EXPERIMENTS SUMMARY")
    print("="*80)
    
    # Group by format and show final epoch results
    final_epoch = df[df['epoch'] == CONFIG['num_epochs']]
    
    print(f"\nFinal Epoch ({CONFIG['num_epochs']}) Results:\n")
    print(f"{'Format':<15} {'Variant':<20} {'Train Acc':<12} {'Val Acc':<12} {'Time (s)':<12} {'Throughput':<15}")
    print("-" * 90)
    
    for _, row in final_epoch.iterrows():
        print(f"{row['format']:<15} {row['variant']:<20} "
              f"{row['train_acc']:>10.2f}% {row['val_acc']:>10.2f}% "
              f"{row['train_time']:>10.2f}s {row['train_samples_per_sec']:>12.1f} samp/s")
    
    # Resource utilization summary
    print(f"\n\nResource Utilization (Mean):\n")
    print(f"{'Format':<15} {'Variant':<20} {'GPU %':<10} {'CPU %':<10} {'Disk R (MB/s)':<15} {'Disk W (MB/s)':<15}")
    print("-" * 90)
    
    for _, row in final_epoch.iterrows():
        gpu_util = row.get('gpu_util_mean', 0) or 0
        cpu_util = row.get('cpu_util_mean', 0) or 0
        disk_r = row.get('disk_read_mb_s_mean', 0) or 0
        disk_w = row.get('disk_write_mb_s_mean', 0) or 0
        
        print(f"{row['format']:<15} {row['variant']:<20} "
              f"{gpu_util:>8.1f}% {cpu_util:>8.1f}% "
              f"{disk_r:>13.2f} {disk_w:>13.2f}")
    
    print("\n" + "="*80)
    print(f"\nResults saved to: {SUMMARY_CSV}")
    print(f"Resource logs saved to: {RUN_DIR}")
else:
    print("No results available")
# Out:
# ================================================================================
# BASELINE EXPERIMENTS SUMMARY
# ================================================================================
#
# Final Epoch (3) Results:
#
# Format          Variant              Train Acc    Val Acc      Time (s)     Throughput
# ------------------------------------------------------------------------------------------
# webdataset      shard256_none             61.74%      43.45%    2444.17s         20.5 samp/s
# csv             default                   59.87%      61.41%    2349.66s         21.3 samp/s
# tfrecord        shard256_none             59.04%      58.42%    2358.10s         21.2 samp/s
# lmdb            compress_none             59.36%      59.79%    2322.17s         21.5 samp/s
#
#
# Resource Utilization (Mean):
#
# Format          Variant              GPU %      CPU %      Disk R (MB/s)   Disk W (MB/s)
# ------------------------------------------------------------------------------------------
# webdataset      shard256_none             nan%    792.8%          0.13          0.00
# csv             default                   nan%    792.5%          0.05          0.00
# tfrecord        shard256_none             nan%    795.2%          0.05          0.00
# lmdb            compress_none             nan%    795.2%          0.00          0.00
#
# ================================================================================
#
# Results saved to: C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines\summary.csv
# Resource logs saved to: C:\Users\arjya\Fall 2025\Systems for ML\Project 1\SML\format-matters\runs\20251127-145553\train_baselines

# %% [markdown]
# ## ✅ Baseline Experiments Complete
#
# **What was measured:**
# - Training throughput (samples/second)
# - Time per epoch
# - Model accuracy (train and validation)
# - GPU utilization
# - CPU utilization
# - Disk I/O (read/write rates)
# - Memory usage
#
# **Key Insights:**
# - Compare training throughput across formats
# - Identify bottlenecks (GPU idle time, disk I/O)
# - Understand resource utilization patterns
#
# **Next steps:**
# 1. Run scaling experiments (21_train_scaling.ipynb)
# 2. Analyze results (30_analysis_summary.ipynb)
# 3. Create visualizations (31_analysis_plots.ipynb)
# 4. Generate decision guide (40_decision_guide.ipynb)
